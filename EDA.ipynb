# %% [markdown]
# <a href="https://colab.research.google.com/github/tavishijain3/Breast-Cancer-Data-Analysis-and-Prediction/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Step 1: Loading the Dataset, Exploring Dimensions, Summary, and Data Handling**
#
# ## 1.1 Load Dataset

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
url = 'https://raw.githubusercontent.com/salemprakash/EDA/main/Data/bcancer.csv'
df = pd.read_csv(url)

# View the first few rows of the dataset
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ## 1.2 Explore Dimensions and Summary

# %%
# Check dataset dimensions
print(f"The dataset contains {df.shape[0]} rows and {df.shape[1]} columns.")

# Basic information of the dataset
df.info()

# Statistical summary of numerical features
df.describe()
# Out:
# The dataset contains 569 rows and 33 columns.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
# ...

# %% [markdown]
# ## 1.3 Data Handling: Check and fill missing values in numeric columns with median and non-numeric columns with mode.

# %%
# Checking for missing values
print(df.isnull().sum())

# Separating numeric columns from non-numeric ones
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
non_numeric_cols = df.select_dtypes(exclude=['float64', 'int64']).columns

# Fill missing values for numeric columns with the median
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# Fill missing values for non-numeric columns (if needed) with the mode (most frequent value)
for col in non_numeric_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

# Check if all missing values are filled
print(df.isnull().sum())
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# Drop the 'Unnamed: 32' column
df.drop('Unnamed: 32', axis=1, inplace=True)

# %% [markdown]
# # **Step 2: Data Cleaning and Handling**
# ## 2.1 Removing Duplicates

# %%
# Check for duplicate rows
duplicate_count = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")

# Remove duplicates
df = df.drop_duplicates()
print(f"Shape after removing duplicates: {df.shape}")
# Out:
# Number of duplicate rows: 0
# Shape after removing duplicates: (569, 32)

# %% [markdown]
# ## 2.2 Outlier Detection and Filtering

# %%
# Detect outliers using boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, palette='coolwarm')
plt.title('Boxplot for Outlier Detection (Reg. No.: 21BDS0113)', fontsize=22, weight='bold')
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add grid lines for better readability
plt.tight_layout()
plt.show()

# Filter out outliers based on certain criteria (example: filtering radius_mean > threshold)
# Adjust threshold as necessary;
threshold = 30
df_filtered = df[df['radius_mean'] < threshold]
print(f"Shape after filtering out outliers: {df_filtered.shape}")
# Out:
# Shape after filtering out outliers: (569, 32)

# %% [markdown]
# # **Step 3: Univariate Analysis**
# ## 3.1 Histogram

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style and palette
sns.set(style="whitegrid")
plt.style.use('ggplot')

color = '#6a0dad'

# Select only numeric columns
df_numeric = df.select_dtypes(include=['float64', 'int64'])

# Calculate number of rows needed based on the number of features
num_features = len(df_numeric.columns)
num_cols = 3  # Number of columns in the subplot grid
num_rows = (num_features // num_cols) + (num_features % num_cols > 0)

# Create subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 5 * num_rows))
axes = axes.flatten()  # Flatten the axes array for easy iteration

# Plot each feature's histogram
for i, column in enumerate(df_numeric.columns):
    ax = axes[i]
    df_numeric[column].plot(kind='hist', ax=ax, bins=20, color=color, edgecolor='black', linewidth=1.0)
    ax.set_title(column, fontsize=12, weight='bold')
    ax.set_xlabel('Values', fontsize=10)
    ax.set_ylabel('Frequency', fontsize=10)

# Remove any unused subplots (if the grid is larger than the number of plots)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.suptitle('Histogram of All Features (Reg. No.: 21BDS0113)', fontsize=22, weight='bold')
plt.subplots_adjust(top=0.95, hspace=0.4, wspace=0.3)
plt.show()

# %% [markdown]
# ## 3.2 Boxplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style and palette
sns.set(style="whitegrid")
plt.style.use('ggplot')

# Select only numeric columns
df_numeric = df.select_dtypes(include=['float64', 'int64'])

# Define a color palette with diverse colors for clarity
palette = sns.color_palette("coolwarm", n_colors=len(df_numeric.columns))

# Create the boxplot
plt.figure(figsize=(15, 10))
sns.boxplot(data=df_numeric, palette=palette, width=0.5)

# Enhance plot aesthetics
plt.title('Boxplot for All Features (Reg. No.: 21BDS0113)', fontsize=22, weight='bold')
plt.xlabel('Features', fontsize=15)
plt.ylabel('Values', fontsize=15)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # grid lines for better readability

# Show plot
plt.tight_layout()
plt.show()

# %%
# Convert 'diagnosis' column to numerical values
df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B': 0})

# %% [markdown]
# # **Step 4: Bivariate Analysis**
# ## 4.1 Correlation Heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

# Define a custom purple-pink colormap with more distinct gradient
colors = ["#f7e1ea", "#e08cb5", "#b96588", "#6D28D9"]  # Lighter pink to dark purple for contrast
cmap = LinearSegmentedColormap.from_list("purple_pink", colors, N=256)

# Select the relevant columns for analysis
columns_of_interest = [
    'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
    'smoothness_mean', 'compactness_mean', 'concavity_mean',
    'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean'
]
df_relevant = df[columns_of_interest]

# Compute the correlation matrix for the selected columns
corr = df_relevant.corr()

# Create the heatmap
plt.figure(figsize=(14, 10))  # Adjusted size for better readability
sns.heatmap(
    corr,
    annot=True,  # Show correlation values
    cmap=cmap,  # Custom purple-pink colormap with better contrast
    fmt='.2f',  # Format annotations
    linewidths=0.5,  # Add separation lines between cells
    vmin=-1, vmax=1,  # Set the color range
    center=0,  # Center the colormap at 0 for better clarity of positive/negative correlations
    cbar_kws={"shrink": .8},  # Adjust color bar size
    annot_kws={"size": 12, "weight": 'bold'}  # Annotation font size and weight
)

# Customize the plot
plt.title('Correlation Matrix Heatmap of Selected Features (Reg. No.: 21BDS0113)', fontsize=22, weight='bold')
plt.xticks(rotation=45, ha='right', fontsize=12)  # Rotate x-axis labels for better readability
plt.yticks(rotation=0, fontsize=12)  # Keep y-axis labels horizontal

# Show the plot
plt.tight_layout()  # Adjust layout to fit elements
plt.show()

# %% [markdown]
# ## 4.2 Scatter Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define a custom purple-pink palette
palette = sns.color_palette(["#D5A6C4", "#6D28D9"])  # Light pink and dark purple

# Create the scatter plot
plt.figure(figsize=(12, 8))  # Adjust size for better readability
sns.scatterplot(
    x='radius_mean',
    y='texture_mean',
    hue='diagnosis',
    data=df,
    palette=palette,  # Custom color palette
    style='diagnosis',  # Different marker styles for each category
    s=100,  # Marker size
    edgecolor='black',  # Add black edge around markers
    alpha=0.8  # Slightly transparent markers
)

# Customize the plot
plt.title('Scatter Plot of Radius Mean vs Texture Mean (Reg. No.: 21BDS0113)', fontsize=22, weight='bold')
plt.xlabel('Radius Mean', fontsize=16, weight='bold')
plt.ylabel('Texture Mean', fontsize=16, weight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)  # Add grid lines

# Show the legend with a clear title
plt.legend(title='Diagnosis', title_fontsize='13', fontsize='12', loc='best')

# Show the plot
plt.tight_layout()  # Adjust layout to fit elements
plt.show()

# %% [markdown]
# # **Step 5: Multivariate Analysis**
# ## 5.1 Pairplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define a custom purple-pink palette
palette = sns.color_palette(["#D5A6C4", "#6D28D9"])  # Light pink and dark purple

# Select relevant features for the pairplot
features_of_interest = [
    'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
    'smoothness_mean', 'compactness_mean'
]
df_relevant = df[features_of_interest + ['diagnosis']]

# Create the pairplot
pairplot = sns.pairplot(
    df_relevant,
    hue='diagnosis',
    palette=palette,  # Custom color palette
    diag_kind='hist',  # Histogram on the diagonal
    plot_kws={'alpha': 0.7, 'edgecolor': 'w', 's': 80},  # Custom marker style
)

# Customize the plot
pairplot.fig.suptitle('Pairplot of Multiple Features (Reg. No.: 21BDS0113)', fontsize=22, weight='bold', y=1.02)
pairplot.fig.subplots_adjust(top=0.95)  # Adjust the space to fit suptitle

# Show the plot
plt.show()

# %% [markdown]
# # **Module 2 Implementation:**
# ## 6.1 Merging Data

# %%
# Example: Creating a secondary dataframe to merge (based on 'diagnosis')
df_merge = df[['id', 'diagnosis']]
df_merged = pd.merge(df, df_merge, on='id')

# View the merged dataframe
df_merged.head()
# Out:
#          id  diagnosis_x  radius_mean  texture_mean  perimeter_mean  \
# 0    842302            1        17.99         10.38          122.80
# 1    842517            1        20.57         17.77          132.90
# 2  84300903            1        19.69         21.25          130.00
# 3  84348301            1        11.42         20.38           77.58
# 4  84358402            1        20.29         14.34          135.10
#
#    area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0     1001.0          0.11840           0.27760          0.3001
# 1     1326.0          0.08474           0.07864          0.0869
# 2     1203.0          0.10960           0.15990          0.1974
# 3      386.1          0.14250           0.28390          0.2414
# 4     1297.0          0.10030           0.13280          0.1980
#
#    concave points_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0              0.14710  ...          17.33           184.60      2019.0
# ...

# %% [markdown]
# ## 6.2 Reshaping with Hierarchical Indexing

# %%
# Setting a hierarchical index based on diagnosis and radius_mean
df.set_index(['diagnosis', 'radius_mean'], inplace=True)
df.head()

# Resetting the index back
df.reset_index(inplace=True)
df.head()
# Out:
#    diagnosis  radius_mean        id  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99    842302         10.38          122.80     1001.0
# 1          1        20.57    842517         17.77          132.90     1326.0
# 2          1        19.69  84300903         21.25          130.00     1203.0
# 3          1        11.42  84348301         20.38           77.58      386.1
# 4          1        20.29  84358402         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ## 6.3 Transformation Techniques

# %%
# Applying log transformation to reduce skewness
df['log_radius_mean'] = np.log(df['radius_mean'] + 1)  # Adding 1 to avoid log(0)

# View transformed column
print(df[['radius_mean', 'log_radius_mean']].head())
# Out:
#    radius_mean  log_radius_mean
# 0        17.99         2.943913
# 1        20.57         3.071303
# 2        19.69         3.029650
# 3        11.42         2.519308
# 4        20.29         3.058237

# %% [markdown]
# ## 6.4 Discretization and Binning

# %%
# Discretizing the 'radius_mean' column into bins
bins = [0, 10, 20, 30]
labels = ['Small', 'Medium', 'Large']
df['radius_bin'] = pd.cut(df['radius_mean'], bins=bins, labels=labels)

# View the binned column
df[['radius_mean', 'radius_bin']].head()
# Out:
#    radius_mean radius_bin
# 0        17.99     Medium
# 1        20.57      Large
# 2        19.69     Medium
# 3        11.42     Medium
# 4        20.29      Large

# %% [markdown]
# # **Module 3 Implementation:**
# ## 7.1 Time-Series Analysis
# #### Since our dataset isn't time-series based, this can be adapted by using a mock column or working with the timestamp for exploratory purposes. However, this step can be omitted if not relevant to the current dataset.

# %% [markdown]
# ## 7.2 Advanced Bivariate Analysis

# %%
# Bar plot for categorical feature - diagnosis
import matplotlib.pyplot as plt
import seaborn as sns

# Define a color scheme
colors = ["#D5A6C4", "#6D28D9"]

# Create the bar plot for the categorical feature 'diagnosis'
plt.figure(figsize=(10, 6))
sns.countplot(x='diagnosis', data=df, palette=colors, edgecolor='black')

# Customize the plot
plt.title('Diagnosis Distribution (Malignant vs Benign) (Reg. No.: 21BDS0113)', fontsize=22, weight='bold')
plt.xlabel('Diagnosis', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Show the plot
plt.show()
# Out:
# <ipython-input-18-5a38f0fda142>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='diagnosis', data=df, palette=colors, edgecolor='black')

# %% [markdown]
# ## 7.3 Grouping and Aggregation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
url = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/bcancer.csv"
df = pd.read_csv(url)

# Check for NaN values in the 'diagnosis' column
print("Number of NaN values in 'diagnosis':", df['diagnosis'].isna().sum())

# Map 'diagnosis' to numeric values
df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B': 0})

# Drop rows with NaN values in 'diagnosis' if any
df.dropna(subset=['diagnosis'], inplace=True)

# Convert to integer type
df['diagnosis'] = df['diagnosis'].astype(int)

# Grouping by 'diagnosis' and calculating the mean for each feature
df_grouped = df.groupby('diagnosis').mean()

# Transpose the grouped DataFrame for better visualization
df_grouped = df_grouped.T

# Set figure size and define custom color palette
plt.figure(figsize=(14, 8))
colors = ["#6A0DAD", "#FF69B4"]

# Create the bar plot with enhanced aesthetics
bars = plt.bar(df_grouped.index, df_grouped[0], color=colors[0], edgecolor='black', label='Benign', alpha=0.8)
plt.bar(df_grouped.index, df_grouped[1], bottom=df_grouped[0], color=colors[1], edgecolor='black', label='Malignant', alpha=0.8)

# Add annotations on top of bars
for i in range(len(df_grouped)):
    total_value = df_grouped[0].iloc[i] + df_grouped[1].iloc[i]
    if pd.notna(total_value):  # Ensure the total value is finite
        plt.text(i, total_value - 0.05,
                 f'{df_grouped[0].iloc[i]:.2f}', ha='center', fontsize=10, color='white', weight='bold')

# Customize plot appearance
plt.title('Average Values of Features by Diagnosis (Reg. No.: 21BDS0113)', fontsize=22, weight='bold', color='#6A0DAD')
plt.xlabel('Features', fontsize=16, weight='bold', color='#6A0DAD')
plt.ylabel('Average Value', fontsize=16, weight='bold', color='#6A0DAD')
plt.xticks(rotation=45, ha='right', fontsize=12, color='#6A0DAD')
plt.yticks(fontsize=12, color='#6A0DAD')
plt.legend(title='Diagnosis (0: Benign, 1: Malignant)', fontsize=12, title_fontsize='13')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add a light background grid for better readability
plt.gca().set_facecolor('#f7f7f7')

# Display the plot with a neat layout
plt.tight_layout()
plt.show()
# Out:
# Number of NaN values in 'diagnosis': 0
